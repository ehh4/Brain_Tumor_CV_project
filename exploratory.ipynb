# %%
import pandas as pd
from ultralytics import YOLO
from IPython.display import Image
from IPython.display import display

# %%
# model = YOLO('yolov8n-seg.yaml')  # build a new model from YAML
# res = model.train(data='/Users/dianechiang/Desktop/data515/data_515_brain_tumor_computer_vision/data/ins_seg_yv8/data.yaml', epochs=200, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.8 torch-2.2.0 CPU (Apple M1 Pro)
# ...

# %%
res_png = Image("/opt/homebrew/runs/segment/train4/results.png")
display(res_png)

# %%
conf_mat = Image("/opt/homebrew/runs/segment/train4/confusion_matrix_normalized.png", width=800)
display(conf_mat)

# %%
# Load a model
model = YOLO('/opt/homebrew/runs/segment/train4/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model.predict(source='data/ins_seg_yv8/test/images/y8_jpg.rf.7cf3d7348c30f5ac6df124f6b261da32.jpg', save=True, save_txt=True)
# Out:
# image 1/1 /Users/dianechiang/Desktop/data515/data_515_brain_tumor_computer_vision/data/ins_seg_yv8/test/images/y8_jpg.rf.7cf3d7348c30f5ac6df124f6b261da32.jpg: 640x640 1 tumor_moderate_chance, 125.4ms
# Speed: 2.5ms preprocess, 125.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /opt/homebrew/runs/segment/predict2
# 1 label saved to /opt/homebrew/runs/segment/predict2/labels

# %%
p_im = Image("/opt/homebrew/runs/segment/predict2/y8_jpg.rf.7cf3d7348c30f5ac6df124f6b261da32.jpg")
display(p_im)
